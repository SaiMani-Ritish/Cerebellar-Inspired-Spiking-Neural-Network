# %% [markdown]
# # Smoke test: `train.py` (import only)

# %%
print("Importing snn_research.train ...")
try:
    import sys
    sys.path.insert(0, r"C:\Users\sriha\Downloads\SNN")
    import snn_research.train as train
    print("train import OK")
    print("Has main:", callable(getattr(train, 'main', None)))
    print("Has run_experiment:", callable(getattr(train, 'run_experiment', None)))
except Exception as e:
    print("train import FAILED:", repr(e))

print("TRAIN IMPORT SMOKE TEST DONE")
# Out:
# Importing snn_research.train ...
# train import OK
# Has main: True
# Has run_experiment: True
# TRAIN IMPORT SMOKE TEST DONE
